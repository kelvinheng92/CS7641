# %%
import mlrose_hiive as mlrose
import pandas as pd
import numpy as np
import math
import time
from sklearn.model_selection import train_test_split, cross_validate, RandomizedSearchCV, StratifiedShuffleSplit
from sklearn.metrics import make_scorer, roc_auc_score, accuracy_score, average_precision_score

# %%
random_state = 2020
max_attempts = 50
max_iters = 1000
N = 3
init_state_seeds = range(N)

# %%
trainval_df = pd.read_csv('dataset2/processed_trainval_data.csv')
display(trainval_df.shape)
display(trainval_df.head())
# Out:
# (1552, 28)
#    X_Minimum  Square_Index  Length_of_Conveyer  Y_Perimeter  Edges_Y_Index  \
# 0   0.557185      0.579812            0.234568     0.000606       1.000000
# 1   0.000000      0.109307            0.231041     0.006556       1.000000
# 2   0.024047      0.955430            0.305115     0.025784       0.336801
# 3   0.022874      0.973480            0.308642     0.017024       0.464376
# 4   0.687977      0.573359            0.222222     0.001377       1.000000
#
#    Maximum_of_Luminosity  X_Perimeter  Orientation_Index  Luminosity_Index  \
# 0               0.481481     0.000670           0.709991          0.585558
# 1               0.259259     0.008711           0.945327          0.352651
# 2               0.490741     0.072174           0.477531          0.552651
# 3               0.490741     0.047669           0.513088          0.553870
# 4               0.393519     0.001723           0.713219          0.492566
#
#    Empty_Index  ...  Pixels_Areas  SigmoidOfAreas  LogOfAreas  \
# 0     0.264859  ...      0.000400        0.079682    0.306859
# 1     0.547410  ...      0.005306        0.999886    0.534254
# 2     0.521665  ...      0.104118        1.000000    0.798800
# 3     0.432673  ...      0.087172        1.000000    0.782989
# 4     0.358618  ...      0.001677        0.593871    0.432261
#
#    Sum_of_Luminosity  TypeOfSteel_A400  TypeOfSteel_A300  Y_Minimum  \
# 0           0.000648               1.0               0.0   0.065121
# 1           0.005177               0.0               1.0   0.051659
# 2           0.159364               1.0               0.0   0.075772
# 3           0.133714               1.0               0.0   0.113521
# 4           0.002284               0.0               1.0   0.082095
#
#    Log_X_Index  X_Maximum  label
# 0     0.196206   0.557636      0
# 1     0.304749   0.005851      0
# 2     0.705600   0.127560      0
# 3     0.674083   0.107080      0
# 4     0.315567   0.692803      0
#
# [5 rows x 28 columns]

# %%
test_df = pd.read_csv('dataset2/processed_test_data.csv')
display(test_df.shape)
display(test_df.head())
# Out:
# (389, 28)
#    X_Minimum  Square_Index  Length_of_Conveyer  Y_Perimeter  Edges_Y_Index  \
# 0   0.344868      0.887970            0.746032     0.000441       1.000000
# 1   0.026979      0.404154            0.234568     0.005344       0.528163
# 2   0.059238      0.928002            0.700176     0.000716       1.000000
# 3   0.078592      0.246647            0.227513     0.005124       0.921711
# 4   0.357771      1.000000            0.282187     0.000826       0.934321
#
#    Maximum_of_Luminosity  X_Perimeter  Orientation_Index  Luminosity_Index  \
# 0               0.416667     0.000766           0.555858          0.539732
# 1               0.439815     0.018666           0.201796          0.497867
# 2               0.416667     0.001532           0.535835          0.511883
# 3               0.402778     0.008806           0.876633          0.515174
# 4               0.416667     0.001244           0.499823          0.552834
#
#    Empty_Index  ...  Pixels_Areas  SigmoidOfAreas  LogOfAreas  \
# 0     0.250132  ...      0.000347        0.066175    0.294796
# 1     0.445598  ...      0.027042        1.000000    0.678928
# 2     0.244517  ...      0.000904        0.216459    0.377885
# 3     0.623795  ...      0.005142        1.000000    0.531468
# 4     0.249603  ...      0.001114        0.289444    0.396195
#
#    Sum_of_Luminosity  TypeOfSteel_A400  TypeOfSteel_A300  Y_Minimum  \
# 0           0.000517               0.0               1.0   0.134447
# 1           0.037291               1.0               0.0   0.014068
# 2           0.001279               0.0               1.0   0.112502
# 3           0.007335               0.0               1.0   0.031193
# 4           0.001704               1.0               0.0   0.040238
#
#    Log_X_Index  X_Maximum  label
# 0     0.217122   0.346401      0
# 1     0.656161   0.101814      0
# 2     0.293138   0.064365      0
# 3     0.375536   0.088941      0
# 4     0.315567   0.363370      0
#
# [5 rows x 28 columns]

# %%
features = list(set(trainval_df.columns) - set(['label']))
label = ['label']
trainval_X = trainval_df[features]
trainval_Y = trainval_df[label]
test_X = test_df[features]
test_Y = test_df[label]

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
sss.get_n_splits(trainval_X, trainval_Y)
for train_index, test_index in sss.split(trainval_X, trainval_Y):
    train_X, val_X = trainval_X.iloc[train_index], trainval_X.iloc[test_index]
    train_Y, val_Y = trainval_Y.iloc[train_index], trainval_Y.iloc[test_index]

# %% [markdown]
# ### Gradient Descent

# %%
optimal_val_aucprc = 0
start_time = time.time()
best_val_aucprc = []
curves = []
for idx, init_state_seed in enumerate(init_state_seeds):

    nn_model = mlrose.NeuralNetwork(hidden_nodes=[20, 8], activation='relu', \
                                     algorithm='gradient_descent', max_iters=max_iters, \
                                     bias=True, is_classifier=True, learning_rate=0.01, \
                                     early_stopping=False, 
#                                          restarts=restarts, schedule=schedule, \
#                                          pop_size=pop_size, mutation_prob=mutation_prob, \
                                     max_attempts=max_attempts, random_state=init_state_seed, curve=True)

    nn_model.fit(train_X, train_Y)

    loss = nn_model.loss
    curve = nn_model.fitness_curve
    curves.append(curve)

    train_y_pred = nn_model.predict(train_X)
    train_aucprc = average_precision_score(train_Y, train_y_pred)

    val_y_pred = nn_model.predict(val_X)
    val_aucprc = average_precision_score(val_Y, val_y_pred)
    best_val_aucprc.append(val_aucprc)

end_time = time.time()
total_time = round(end_time - start_time, 5)
average_time_taken = round(total_time / N, 5)
average_best_val_aucprc = np.mean(best_val_aucprc)
if average_best_val_aucprc > optimal_val_aucprc:
    optimal_val_aucprc = average_best_val_aucprc
    best_time_taken = average_time_taken

print(f'------- total_time = {total_time} -------')
print(f'The average time taken for one run to reach the best state is {average_time_taken} seconds')
print(f'The average validation aucprc at the best state is {average_best_val_aucprc}')
print('\n')

print(f'time taken is {best_time_taken}')
print(f'optimal aucprc is {optimal_val_aucprc}')
# Out:
# ------- total_time = 11.04336 -------
# The average time taken for one run to reach the best state is 3.68112 seconds
# The average validation aucprc at the best state is 0.029996976942314558
#
#
# time taken is 3.68112
# optimal aucprc is 0.029996976942314558

# %% [markdown]
# ### Random Hill Climb

# %%
optimal_val_aucprc = 0
for restarts in [5, 10]:
    start_time = time.time()
    best_val_aucprc = []
    curves = []
    for idx, init_state_seed in enumerate(init_state_seeds):

        nn_model = mlrose.NeuralNetwork(hidden_nodes=[20, 8], activation='relu', \
                                         algorithm='random_hill_climb', max_iters=max_iters, \
                                         bias=True, is_classifier=True, learning_rate=0.01, \
                                         early_stopping=False, 
#                                          restarts=restarts, schedule=schedule, \
#                                          pop_size=pop_size, mutation_prob=mutation_prob, \
                                         max_attempts=max_attempts, random_state=init_state_seed, curve=True)

        nn_model.fit(train_X, train_Y)
        
        loss = nn_model.loss
        curve = nn_model.fitness_curve
        curves.append(curve)

        train_y_pred = nn_model.predict(train_X)
        train_aucprc = average_precision_score(train_Y, train_y_pred)

        val_y_pred = nn_model.predict(val_X)
        val_aucprc = average_precision_score(val_Y, val_y_pred)
        best_val_aucprc.append(val_aucprc)

    end_time = time.time()
    total_time = round(end_time - start_time, 5)
    average_time_taken = round(total_time / N, 5)
    average_best_val_aucprc = np.mean(best_val_aucprc)
    if average_best_val_aucprc > optimal_val_aucprc:
        optimal_val_aucprc = average_best_val_aucprc
        best_time_taken = average_time_taken
        params = f'restarts={restarts}'
        
    print(f'------- restarts = {restarts}, total_time = {total_time} -------')
    print(f'The average time taken for one run to reach the best state is {average_time_taken} seconds')
    print(f'The average validation aucprc at the best state is {average_best_val_aucprc}')
    print('\n')

print(f'best params is {params}')
print(f'time taken is {best_time_taken}')
print(f'optimal aucprc is {optimal_val_aucprc}')
# Out:
# ------- restarts = 5, total_time = 5.87055 -------
# The average time taken for one run to reach the best state is 1.95685 seconds
# The average validation aucprc at the best state is 0.04761207371632148
#
#
# ------- restarts = 10, total_time = 6.10844 -------
# The average time taken for one run to reach the best state is 2.03615 seconds
# The average validation aucprc at the best state is 0.03800699497940994
#
#
# best params is restarts=5
# time taken is 1.95685
# optimal aucprc is 0.04761207371632148

# %% [markdown]
# ### Simulated Annealing

# %%
optimal_val_aucprc = 0
for exp_const in [0.001, 0.005, 0.01]:
    for init_temp in [0.3, 0.6]:
        start_time = time.time()
        best_val_aucprc = []
        curves = []
        for idx, init_state_seed in enumerate(init_state_seeds):
            schedule = mlrose.ExpDecay(init_temp = init_temp, exp_const = exp_const)
            nn_model = mlrose.NeuralNetwork(hidden_nodes=[20, 8], activation='relu', \
                                             algorithm='simulated_annealing', max_iters=max_iters, \
                                             bias=True, is_classifier=True, learning_rate=0.01, \
                                             early_stopping=False, 
#                                              restarts=restarts,
                                             schedule=schedule,
#                                              pop_size=pop_size, mutation_prob=mutation_prob, \
                                             max_attempts=max_attempts, random_state=init_state_seed, curve=True)

            nn_model.fit(train_X, train_Y)

            loss = nn_model.loss
            curve = nn_model.fitness_curve
            curves.append(curve)

            train_y_pred = nn_model.predict(train_X)
            train_aucprc = average_precision_score(train_Y, train_y_pred)

            val_y_pred = nn_model.predict(val_X)
            val_aucprc = average_precision_score(val_Y, val_y_pred)
            best_val_aucprc.append(val_aucprc)

        end_time = time.time()
        total_time = round(end_time - start_time, 5)
        average_time_taken = round(total_time / N, 5)
        average_best_val_aucprc = np.mean(best_val_aucprc)
        if average_best_val_aucprc > optimal_val_aucprc:
            optimal_val_aucprc = average_best_val_aucprc
            best_time_taken = average_time_taken
            params = f'exp_const={exp_const}_init_temp={init_temp}'

        print(f'------- exp_const = {exp_const}, init_temp = {init_temp}, total_time = {total_time} -------')
        print(f'The average time taken for one run to reach the best state is {average_time_taken} seconds')
        print(f'The average validation aucprc at the best state is {average_best_val_aucprc}')
        print('\n')

print(f'best params is {params}')
print(f'time taken is {best_time_taken}')
print(f'optimal aucprc is {optimal_val_aucprc}')
# Out:
# ------- exp_const = 0.001, init_temp = 0.3, total_time = 8.69185 -------
# The average time taken for one run to reach the best state is 2.89728 seconds
# The average validation aucprc at the best state is 0.03188525122608724
#
#
# ------- exp_const = 0.001, init_temp = 0.6, total_time = 8.6349 -------
# The average time taken for one run to reach the best state is 2.8783 seconds
# The average validation aucprc at the best state is 0.03129950965333297
#
#
# ------- exp_const = 0.005, init_temp = 0.3, total_time = 8.89994 -------
# The average time taken for one run to reach the best state is 2.96665 seconds
# The average validation aucprc at the best state is 0.031656122775850414
#
#
# ------- exp_const = 0.005, init_temp = 0.6, total_time = 9.27534 -------
# The average time taken for one run to reach the best state is 3.09178 seconds
# The average validation aucprc at the best state is 0.031711731136439616
#
#
# ------- exp_const = 0.01, init_temp = 0.3, total_time = 8.54213 -------
# The average time taken for one run to reach the best state is 2.84738 seconds
# The average validation aucprc at the best state is 0.03347226685923707
#
#
# ------- exp_const = 0.01, init_temp = 0.6, total_time = 8.69564 -------
# The average time taken for one run to reach the best state is 2.89855 seconds
# The average validation aucprc at the best state is 0.03306310169421663
#
#
# best params is exp_const=0.01_init_temp=0.3
# time taken is 2.84738
# optimal aucprc is 0.03347226685923707

# %% [markdown]
# ### Genetic Algorithm

# %%
optimal_val_aucprc = 0
for pop_size in [10, 30]:
    for mutation_prob in [0.3, 0.6]:
        start_time = time.time()
        best_val_aucprc = []
        curves = []
        for idx, init_state_seed in enumerate(init_state_seeds):
            schedule = mlrose.ExpDecay(init_temp = init_temp, exp_const = exp_const)
            nn_model = mlrose.NeuralNetwork(hidden_nodes=[20, 8], activation='relu', \
                                             algorithm='genetic_alg', max_iters=max_iters, \
                                             bias=True, is_classifier=True, learning_rate=0.01, \
                                             early_stopping=False, 
#                                              restarts=restarts,
                                             schedule=schedule,
                                             pop_size=pop_size, mutation_prob=mutation_prob, \
                                             max_attempts=max_attempts, random_state=init_state_seed, curve=True)

            nn_model.fit(train_X, train_Y)

            loss = nn_model.loss
            curve = nn_model.fitness_curve
            curves.append(curve)

            train_y_pred = nn_model.predict(train_X)
            train_aucprc = average_precision_score(train_Y, train_y_pred)

            val_y_pred = nn_model.predict(val_X)
            val_aucprc = average_precision_score(val_Y, val_y_pred)
            best_val_aucprc.append(val_aucprc)

        end_time = time.time()
        total_time = round(end_time - start_time, 5)
        average_time_taken = round(total_time / N, 5)
        average_best_val_aucprc = np.mean(best_val_aucprc)
        if average_best_val_aucprc > optimal_val_aucprc:
            optimal_val_aucprc = average_best_val_aucprc
            best_time_taken = average_time_taken
            params = f'pop_size={pop_size}_mutation_prob={mutation_prob}'
            
        print(f'----- pop_size = {pop_size}, mutation_prob = {mutation_prob}, total_time = {total_time} ------')
        print(f'The average time taken for one run to reach the best state is {average_time_taken} seconds')
        print(f'The average validation aucprc at the best state is {average_best_val_aucprc}')
        print('\n')

print(f'best params is {params}')
print(f'time taken is {best_time_taken}')
print(f'optimal aucprc is {optimal_val_aucprc}')
# Out:
# ----- pop_size = 10, mutation_prob = 0.3, total_time = 72.21575 ------
# The average time taken for one run to reach the best state is 24.07192 seconds
# The average validation aucprc at the best state is 0.028938906752411574
#
#
# ----- pop_size = 10, mutation_prob = 0.6, total_time = 77.43348 ------
# The average time taken for one run to reach the best state is 25.81116 seconds
# The average validation aucprc at the best state is 0.028938906752411574
#
#
# ----- pop_size = 30, mutation_prob = 0.3, total_time = 177.7092 ------
# The average time taken for one run to reach the best state is 59.2364 seconds
# The average validation aucprc at the best state is 0.028938906752411574
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-1443f99067aa>", line 18, in <module>
#     nn_model.fit(train_X, train_Y)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/mlrose_hiive/neural/_nn_core.py", line 158, in fit
#     fitness_curve, fitted_weights, loss = self._run_with_ga(problem)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/mlrose_hiive/neural/_nn_core.py", line 196, in _run_with_ga
#     curve=self.curve)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/mlrose_hiive/algorithms/ga.py", line 191, in genetic_alg
#     get_hamming_distance_func=get_hamming_distance_func)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/mlrose_hiive/algorithms/ga.py", line 42, in _genetic_alg_select_parents
#     p=mating_probabilities)
#   File "mtrand.pyx", line 907, in numpy.random.mtrand.RandomState.choice
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/numpy/core/getlimits.py", line 365, in __new__
#     def __new__(cls, dtype):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2034, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/inspect.py", line 1452, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/ultratb.py", line 185, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/Users/kelvin.heng/anaconda3/envs/ml/lib/python3.6/tokenize.py", line 452, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
# ---------------------------------------------------------------------------
